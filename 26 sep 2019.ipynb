# %% [markdown]
# # subplots

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,2)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(1,2,1)
plt.plot(left,'-o')
plt.subplot(1,2,2)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
left=np.array([1,3,5])
right=np.array([2,4,6])
plt.figure()
plt.subplot(2,2,1)
plt.plot(left,'-o')
plt.subplot(2,2,2)
plt.plot(right,'-o')
plt.subplot(2,2,3)
plt.plot(left,'-o')
plt.subplot(2,2,4)
plt.plot(right,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot([1,2,3],np.array([50,60,70]),'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot([1,2,3],np.array([50,30,40]),'-^')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax5.plot(linear_data,'-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.bar(xvals,linear_data,width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
plt.figure()
linear_data=np.array([10,20,30,40])
xvals=range(len(linear_data))
plt.barh(xvals,linear_data,height=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %%
marks=[50,60,70,50,50,30,70,50]
plt.figure()
plt.hist(marks)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1., 0., 0., 0., 0., 4., 0., 1., 0., 2.]),
#  array([30., 34., 38., 42., 46., 50., 54., 58., 62., 66., 70.]),
#  <a list of 10 Patch objects>)

# %%
height_men_at_20=[6,6,5,3,4,2,7]

# %%
plt.figure()
_=plt.boxplot(height_men_at_20,whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.animation as animation
n=100
x=np.random.randn(n)
x
# Out:
# array([-1.12076542,  0.20741943,  0.91490281,  1.11769567, -1.37988229,
#         1.14289282, -0.40747264,  0.36689684,  1.9268929 , -0.17791211,
#        -2.94116154,  0.63784742, -0.22352385,  0.19597599, -0.0874189 ,
#         0.6610763 ,  0.37944343,  1.04644939,  0.31179572,  0.42720324,
#        -0.14232326, -1.24969974, -0.7679047 ,  0.6981834 , -0.69099876,
#        -0.16106253,  0.01071162,  1.9848516 ,  0.87416964,  0.78517184,
#         0.10415022,  0.30458314, -0.49879466, -1.268823  ,  0.93539438,
#         0.11967798,  0.83461529, -1.29212334, -0.75878171,  0.23566823,
#        -0.57347333,  0.45045437, -0.21296537, -0.3222264 , -1.47584505,
#         1.52899788, -1.87480827, -0.34521373,  0.06473079,  0.67930397,
#        -1.29772929,  0.50410079, -0.28378812,  1.21809636,  0.02081452,
#         1.48268324,  1.04093933,  0.14770362, -1.18878477,  1.44908491,
#        -0.17206698,  0.3051963 ,  0.61476884, -0.18333889,  1.47903077,
# ...

# %%
def update(curr):
    if curr==n:
        a.event_source.stop()
    plt.cla()
    bins=np.arange(-4,4,0.5)
    plt.hist(x[:curr],bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sample the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr),[3,27])

# %%
fig=plt.figure()
a=animation.FuncAnimation(fig,update,interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # interactivity

# %%
plt.figure()
data=np.random.rand(10)
plt.plot(data)


def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title(
    'Event at pixels {},{} \nand data {},{}'.format(
        event.x,event.y,event.xdata,event.ydata)
    )
plt.gcf().canvas.mpl_connect('button_press_event',onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 6

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
fruits=pd.read_table('fruit_data_with_colors.txt')
fruits.head()
# Out:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\animation.py", line 1478, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# ...
