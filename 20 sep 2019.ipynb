# %%
import pandas as pd
staff_df=pd.DataFrame([{'Name':'Kelly','Role':'Director od HR'},
                       {'Name':'Sally','Role':'Project manager'},
                        {'Name':'James','Role':'Grader'}])
staff_df=staff_df.set_index('Name')
student_df=pd.DataFrame([{'Name':'James','School':'Business'},
                       {'Name':'Mike','School':'Law'},
                        {'Name':'Sally','School':'Engineering'}])
student_df=student_df.set_index('Name')
staff_df.head()
# Out:
#                   Role
# Name
# Kelly   Director od HR
# Sally  Project manager
# James           Grader

# %%
student_df.head()
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %% [markdown]
# ## joining based on index

# %%
pd.merge(staff_df,student_df,how='outer',left_index=True,right_index=True)
# Out:
#                   Role       School
# Name
# James           Grader     Business
# Kelly   Director od HR          NaN
# Mike               NaN          Law
# Sally  Project manager  Engineering

# %%
pd.merge(staff_df,student_df,how='inner',left_index=True,right_index=True)
# Out:
#                   Role       School
# Name
# Sally  Project manager  Engineering
# James           Grader     Business

# %%
pd.merge(staff_df,student_df,how='left',left_index=True,right_index=True)
# Out:
#                   Role       School
# Name
# Kelly   Director od HR          NaN
# Sally  Project manager  Engineering
# James           Grader     Business

# %%
pd.merge(staff_df,student_df,how='right',left_index=True,right_index=True)
# Out:
#                   Role       School
# Name
# James           Grader     Business
# Mike               NaN          Law
# Sally  Project manager  Engineering

# %% [markdown]
# ## joining based on particular column

# %%
staff_df=staff_df.reset_index()
student_df=student_df.reset_index()
pd.merge(staff_df,student_df,how='left',left_on='Name',right_on='Name')
# Out:
#     Name             Role       School
# 0  Kelly   Director od HR          NaN
# 1  Sally  Project manager  Engineering
# 2  James           Grader     Business

# %%
staff_df=pd.DataFrame([{'Name':'Kelly','Role':'Director od HR','Location':'nsp'},
                       {'Name':'Sally','Role':'Project manager','Location':'razole'},
                        {'Name':'James','Role':'Grader','Location':'hyd'}])
staff_df=staff_df.set_index('Name')
student_df=pd.DataFrame([{'Name':'James','School':'Business','Location':'pkl'},
                       {'Name':'Mike','School':'Law','Location':'bvrm'},
                        {'Name':'Sally','School':'Engineering','Location':'amp'}])
student_df=student_df.set_index('Name')
staff_df.head()
# Out:
#       Location             Role
# Name
# Kelly      nsp   Director od HR
# Sally   razole  Project manager
# James      hyd           Grader

# %%
student_df.head()
# Out:
#       Location       School
# Name
# James      pkl     Business
# Mike      bvrm          Law
# Sally      amp  Engineering

# %%
pd.merge(staff_df,student_df,how='outer',left_index=True,right_index=True)
# Out:
#       Location_x             Role Location_y       School
# Name
# James        hyd           Grader        pkl     Business
# Kelly        nsp   Director od HR        NaN          NaN
# Mike         NaN              NaN       bvrm          Law
# Sally     razole  Project manager        amp  Engineering

# %%
import pandas as pd
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
import numpy as np
def min_max(row):
    data=row[['POPESTIMATE2010',
             'POPESTIMATE2011',
             'POPESTIMATE2012',
             'POPESTIMATE2013',
             'POPESTIMATE2014',
             'POPESTIMATE2015']]
    return pd.Series({'min':np.min(data),'max':np.max(data)})

# %%
df[['min','max']]=df.apply(min_max,axis=1)
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2013  \
# 0        4779736            4780127          4785161  ...          0.381066
# 1          54571              54571            54660  ...         -3.012349
# 2         182265             182265           183193  ...         21.845705
# 3          27457              27457            27341  ...         -7.056824
# 4          22915              22919            22861  ...         -6.201001
#
#    RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  \
# ...
